# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import models
from tensorflow.keras import layers
keras.__version__
# Out:
# '2.2.4-tf'

# %%
data_10000 = pd.read_csv('training_fullclean.csv',nrows=400000)
# Out:
# /gpfs/data/data2040/tf2/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_20000 = pd.read_csv('testing_fullclean.csv',nrows=400000)

# %%
#rawData = pd.read_csv('datathon_propattributes.csv')
#slicedData = rawData[:100]
data = data_10000
#data = data.drop([])
#data['sale_amt'].describe()

# %%
#Distribution of Property Sale Prices
plt.hist(data.sale_amt, facecolor = 'green')
plt.xlabel('Property Prices ($)')
plt.ylabel('Frequency')
plt.title('Distribution of Property Sale Prices')
plt.show()

# %%
#Distribution of Property Square Feet
plt.hist(data.building_square_feet, 50, facecolor = 'green')
plt.xlabel('Property Size (Square Feet)')
plt.ylabel('Frequency')
plt.title('Distribution of Property Sizes')
plt.show()

# %%
#Distribution of Number of Bedrooms in Property
plt.hist(data.bedrooms, 50, facecolor = 'green')
plt.xlabel('Bedrooms (Units)')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Bedrooms in Property')
plt.show()

# %%
#Distribution of Number of Bathrooms in Property
plt.hist(data.total_baths_calculated, 50, facecolor = 'green')
plt.xlabel('Bathroom (Units)')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Bathrooms in Property')
plt.show()

# %%
#Scatter Plot of Number of Bedrooms and Bathrooms in Property
plt.scatter(data.bedrooms,data.total_baths_calculated,facecolor = 'green')
plt.xlabel('Bathroom (Units)')
plt.ylabel('Bedroom (Units)')
plt.title('Plot of Number of Bedrooms and Bathrooms in Property')
plt.show()

# %% [markdown]
# # Neural Nets Section

# %% [markdown]
# ## Train_val split

# %%
data_10000['land_square_footage'].describe()
# Out:
# count    4.000000e+05
# mean     6.840550e+04
# std      8.082257e+05
# min      0.000000e+00
# 25%      3.485000e+03
# 50%      9.017000e+03
# 75%      2.193900e+04
# max      3.983126e+08
# Name: land_square_footage, dtype: float64

# %%
y = data_10000.sale_amt
yy = data_20000.sale_amt
#X = data_10000[['prop_zip_code','land_square_footage',
#                           'building_square_feet','effective_year_built',
#                          'bedrooms','total_baths_calculated','air_conditioning_Yes',
#                           'condition_Excellent','heating_type_Yes']]
#df[((df.B - df.B.mean()) / df.B.std()).abs() < 3]
X = data_10000.drop(columns = ['sale_amt','stories_cd'])
XX = data_10000.drop(columns = ['sale_amt','stories_cd'])
#X.drop(X.columns[cols],axis=1,inplace=True)
#X = tf.keras.utils.normalize(X)
#X.head

# %%
#list(X)
y = np.log1p(y)
X = np.log1p(X)
yy = np.log1p(yy)
XX = np.log1p(XX)

# %%
X.isnull().values.any()
# Out:
# False

# %%
XX.isnull().values.any()
# Out:
# False

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)
X_test, _, y_test, _ = train_test_split(XX, yy, test_size = 0, random_state=42)

# %% [markdown]
# mean = X_train.mean(axis=0)
# X_train -= mean
# std = X_train.std(axis=0)
# X_train /= std
#
# X_val -= mean
# X_val /= std

# %%
#train_data.shape
X_train.shape
#y_train.shape
# Out:
# (280000, 176)

# %%
X_train.shape[1]
# Out:
# 176

# %%
#val_data.shape
X_val.shape
#y_val.shape
# Out:
# (120000, 176)

# %%
def build_model():
    model = models.Sequential()
    model.add(keras.layers.Dense(256, activation='relu',
                           input_shape=(X_train.shape[1],)))
    #model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dropout(0.1))
    #model.add(keras.layers.Dense(256, activation='relu'))
    #model.add(keras.layers.Dense(256, activation='relu'))
    #model.add(keras.layers.Dense(256, activation='relu'))
    #model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dense(64, activation='relu'))
    #model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dense(1))
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])

    return model

# %%
# fix random seed
seed = 123
np.random.seed(seed)

# %%
# Build the Keras model (already compiled)
model = build_model()
# Train the model (in silent mode, verbose=0)
history = model.fit(X_train, y_train, epochs=40, batch_size=16, validation_data=(X_val, y_val))
# Out:
# Train on 280000 samples, validate on 120000 samples
# Epoch 1/40
# 280000/280000 [==============================] - 76s 273us/sample - loss: 1.0198 - mean_absolute_error: 0.6670 - val_loss: 0.9973 - val_mean_absolute_error: 0.8063
# Epoch 2/40
# 280000/280000 [==============================] - 78s 277us/sample - loss: 0.7870 - mean_absolute_error: 0.5653 - val_loss: 1.2580 - val_mean_absolute_error: 0.9626
# Epoch 3/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.7462 - mean_absolute_error: 0.5379 - val_loss: 1.0537 - val_mean_absolute_error: 0.8405
# Epoch 4/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.7208 - mean_absolute_error: 0.5190 - val_loss: 1.1202 - val_mean_absolute_error: 0.9015
# Epoch 5/40
# 280000/280000 [==============================] - 82s 292us/sample - loss: 0.7080 - mean_absolute_error: 0.5089 - val_loss: 0.9825 - val_mean_absolute_error: 0.7968
# Epoch 6/40
# 280000/280000 [==============================] - 80s 287us/sample - loss: 0.7005 - mean_absolute_error: 0.5028 - val_loss: 0.7268 - val_mean_absolute_error: 0.5859
# Epoch 7/40
# 280000/280000 [==============================] - 81s 291us/sample - loss: 0.6912 - mean_absolute_error: 0.4958 - val_loss: 0.7102 - val_mean_absolute_error: 0.5731
# Epoch 8/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.6842 - mean_absolute_error: 0.4912 - val_loss: 0.9557 - val_mean_absolute_error: 0.7847
# Epoch 9/40
# 280000/280000 [==============================] - 83s 298us/sample - loss: 0.6799 - mean_absolute_error: 0.4877 - val_loss: 0.8436 - val_mean_absolute_error: 0.7160
# Epoch 10/40
# 280000/280000 [==============================] - 82s 294us/sample - loss: 0.6758 - mean_absolute_error: 0.4840 - val_loss: 0.7861 - val_mean_absolute_error: 0.6630
# Epoch 11/40
# 280000/280000 [==============================] - 83s 296us/sample - loss: 0.6689 - mean_absolute_error: 0.4785 - val_loss: 0.6780 - val_mean_absolute_error: 0.5331
# Epoch 12/40
# 280000/280000 [==============================] - 82s 294us/sample - loss: 0.6645 - mean_absolute_error: 0.4749 - val_loss: 0.6892 - val_mean_absolute_error: 0.5474
# Epoch 13/40
# 280000/280000 [==============================] - 84s 300us/sample - loss: 0.6636 - mean_absolute_error: 0.4732 - val_loss: 0.6681 - val_mean_absolute_error: 0.5340
# Epoch 14/40
# 280000/280000 [==============================] - 83s 298us/sample - loss: 0.6592 - mean_absolute_error: 0.4703 - val_loss: 0.6852 - val_mean_absolute_error: 0.5580
# Epoch 15/40
# 280000/280000 [==============================] - 83s 298us/sample - loss: 0.6580 - mean_absolute_error: 0.4695 - val_loss: 0.7104 - val_mean_absolute_error: 0.5701
# Epoch 16/40
# 280000/280000 [==============================] - 82s 292us/sample - loss: 0.6559 - mean_absolute_error: 0.4672 - val_loss: 0.7356 - val_mean_absolute_error: 0.6129
# Epoch 17/40
# 280000/280000 [==============================] - 84s 301us/sample - loss: 0.6545 - mean_absolute_error: 0.4669 - val_loss: 0.7085 - val_mean_absolute_error: 0.5964
# Epoch 18/40
# 280000/280000 [==============================] - 83s 296us/sample - loss: 0.6521 - mean_absolute_error: 0.4652 - val_loss: 0.6177 - val_mean_absolute_error: 0.4367
# Epoch 19/40
# 280000/280000 [==============================] - 83s 295us/sample - loss: 0.6484 - mean_absolute_error: 0.4619 - val_loss: 0.6864 - val_mean_absolute_error: 0.5327
# Epoch 20/40
# 280000/280000 [==============================] - 84s 299us/sample - loss: 0.6475 - mean_absolute_error: 0.4611 - val_loss: 0.6457 - val_mean_absolute_error: 0.5012
# Epoch 21/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.6465 - mean_absolute_error: 0.4606 - val_loss: 0.6845 - val_mean_absolute_error: 0.5617
# Epoch 22/40
# 280000/280000 [==============================] - 84s 300us/sample - loss: 0.6464 - mean_absolute_error: 0.4602 - val_loss: 0.6816 - val_mean_absolute_error: 0.5425
# Epoch 23/40
# 280000/280000 [==============================] - 87s 310us/sample - loss: 0.6445 - mean_absolute_error: 0.4597 - val_loss: 0.7369 - val_mean_absolute_error: 0.6143
# Epoch 24/40
# 280000/280000 [==============================] - 84s 301us/sample - loss: 0.6425 - mean_absolute_error: 0.4586 - val_loss: 0.6384 - val_mean_absolute_error: 0.4706
# Epoch 25/40
# 280000/280000 [==============================] - 85s 303us/sample - loss: 0.6420 - mean_absolute_error: 0.4572 - val_loss: 0.6200 - val_mean_absolute_error: 0.4509
# Epoch 26/40
# 280000/280000 [==============================] - 85s 302us/sample - loss: 0.6405 - mean_absolute_error: 0.4571 - val_loss: 0.6607 - val_mean_absolute_error: 0.5060
# Epoch 27/40
# 280000/280000 [==============================] - 84s 302us/sample - loss: 0.6380 - mean_absolute_error: 0.4555 - val_loss: 0.6190 - val_mean_absolute_error: 0.4470
# Epoch 28/40
# 280000/280000 [==============================] - 84s 301us/sample - loss: 0.6372 - mean_absolute_error: 0.4554 - val_loss: 0.6513 - val_mean_absolute_error: 0.5234
# Epoch 29/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.6370 - mean_absolute_error: 0.4534 - val_loss: 0.6205 - val_mean_absolute_error: 0.4518
# Epoch 30/40
# 280000/280000 [==============================] - 83s 297us/sample - loss: 0.6349 - mean_absolute_error: 0.4534 - val_loss: 0.6629 - val_mean_absolute_error: 0.5392
# Epoch 31/40
# 280000/280000 [==============================] - 84s 299us/sample - loss: 0.6357 - mean_absolute_error: 0.4521 - val_loss: 0.6619 - val_mean_absolute_error: 0.5206
# Epoch 32/40
# 280000/280000 [==============================] - 84s 300us/sample - loss: 0.6351 - mean_absolute_error: 0.4529 - val_loss: 0.6841 - val_mean_absolute_error: 0.5403
# Epoch 33/40
# 280000/280000 [==============================] - 84s 299us/sample - loss: 0.6322 - mean_absolute_error: 0.4511 - val_loss: 0.6371 - val_mean_absolute_error: 0.4825
# Epoch 34/40
# 280000/280000 [==============================] - 84s 298us/sample - loss: 0.6315 - mean_absolute_error: 0.4507 - val_loss: 0.6790 - val_mean_absolute_error: 0.5309
# Epoch 35/40
# 280000/280000 [==============================] - 83s 298us/sample - loss: 0.6297 - mean_absolute_error: 0.4489 - val_loss: 0.6221 - val_mean_absolute_error: 0.4654
# Epoch 36/40
# 280000/280000 [==============================] - 85s 305us/sample - loss: 0.6340 - mean_absolute_error: 0.4501 - val_loss: 0.6239 - val_mean_absolute_error: 0.4615
# Epoch 37/40
# 280000/280000 [==============================] - 89s 318us/sample - loss: 0.6296 - mean_absolute_error: 0.4489 - val_loss: 0.6340 - val_mean_absolute_error: 0.4551
# Epoch 38/40
# 280000/280000 [==============================] - 87s 310us/sample - loss: 0.6285 - mean_absolute_error: 0.4478 - val_loss: 0.6356 - val_mean_absolute_error: 0.5018
# Epoch 39/40
# 280000/280000 [==============================] - 88s 315us/sample - loss: 0.6324 - mean_absolute_error: 0.4492 - val_loss: 0.6710 - val_mean_absolute_error: 0.5602
# Epoch 40/40
# 280000/280000 [==============================] - 89s 317us/sample - loss: 0.6283 - mean_absolute_error: 0.4471 - val_loss: 0.6186 - val_mean_absolute_error: 0.4624

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 256)               45312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 109,249
# Trainable params: 109,249
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# plt.plot(history.history['acc'])
# plt.plot(history.history['val_acc'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='upper left')
# plt.show()
# # summarize history for loss
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='upper left')
# plt.show()

# %%
# Evaluate the model on the validation data
val_mse, val_mae = model.evaluate(X_val, y_val)
# Out:
# 119776/120000 [============================>.] - ETA: 0s - loss: 0.6176 - mean_absolute_error: 0.4623

# %%
results = model.evaluate(X_val, y_val)
results
# Out:
# 119296/120000 [============================>.] - ETA: 0s - loss: 0.6178 - mean_absolute_error: 0.4624
# [0.6185807264328003, 0.46237445]

# %%
preds = model.predict(X_test)

# %%
predss = [preds[i][0] for i in range(len(preds))]
predss = np.array(predss)

# %%
predss_exp = np.exp(predss)+1

# %%
predss_exp
# Out:
# array([520712.03 , 117285.016,  84041.984, ...,  24519.646,  19443.404,
#        188587.16 ], dtype=float32)

# %%
y_test = np.array(y_test)

# %%
y_test_exp = np.exp(y_test) +1

# %%
y_test
# Out:
# array([13.74294094, 11.69525536, 11.37367489, ..., 11.40757606,
#        10.46313191,  9.6091836 ])

# %%
accuracy = ((predss-y_test)/y_test)
#accuracy = accuracy_score(y_val, predss)
accuracy.mean()
# Out:
# 0.00891655767034079

# %%
accuracy_exp = ((predss_exp-y_test_exp)/y_test_exp)
#accuracy = accuracy_score(y_val, predss)
accuracy_exp.mean()
# Out:
# 6.79141826607243

# %%
#evaluate your model on the test set
results = model.evaluate(X_test, y_test)
# Out:
# 399360/400000 [============================>.] - ETA: 0s - loss: 2.7437 - mean_absolute_error: 1.1828

# %%
#run this to see your mae
results[1]
# Out:
# 1.1828089
